# %% [markdown]
# ### Com esse comando, vamos realizar uma atualização na versão da pandas_datareader

# %%
# !pip install -U pandas_datareader
# Out:
# Requirement already up-to-date: pandas_datareader in c:\programdata\anaconda3\lib\site-packages (0.10.0)
# ...

# %% [markdown]
# ### Vamos importar a pandas_datareader

# %%
import pandas_datareader as pdr

# %% [markdown]
# ### Obtendo os dados

# %%
dados = pdr.data.get_data_yahoo('WEGE3.SA',start='2019-01-01')

# %%
dados['Adj Close'].plot();
