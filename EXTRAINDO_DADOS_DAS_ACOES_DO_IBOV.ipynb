# %% [markdown]
# <a href="https://colab.research.google.com/github/victorncg/financas_quantitativas/blob/main/EXTRAINDO_DADOS_DAS_ACOES_DO_IBOV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('/content/IBOVDia_10-07-23.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-d73847f33350> in <cell line: 1>()
# ----> 1 pd.read_csv('/content/IBOVDia_10-07-23.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.read_csv('/content/IBOVDia_10-07-23.csv', encoding='latin-1', sep=';', header=1)
# Out:
#                                 Código        Ação                 Tipo  \
# RRRP3                     3R PETROLEUM  ON      NM          234.689.601
# ALSO3                     ALIANSCSONAE  ON      NM          532.365.440
# ALPA4                       ALPARGATAS  PN      N1          201.952.502
# ABEV3                        AMBEV S/A          ON        4.386.652.506
# ARZZ3                        AREZZO CO  ON  EJ  NM           60.758.326
# ...                                ...         ...                  ...
# VBBR3                            VIBRA  ON      NM        1.114.442.976
# WEGE3                              WEG  ON      NM        1.260.665.218
# YDUQ3                       YDUQS PART  ON      NM          296.015.511
# Quantidade Teórica Total           NaN         NaN       96.071.539.347
# Redutor                            NaN         NaN  17.434.594,76113078
#
#                          Qtde. Teórica  Part. (%)
# RRRP3                            0,365        NaN
# ...

# %%
pd.read_csv('/content/IBOVDia_10-07-23.csv', encoding='latin-1', sep=';', header=1).index[0:-2]
# Out:
# Index(['RRRP3', 'ALSO3', 'ALPA4', 'ABEV3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3',
#        'BBSE3', 'BBDC3', 'BBDC4', 'BRAP4', 'BBAS3', 'BRKM5', 'BRFS3', 'BPAC11',
#        'CRFB3', 'CCRO3', 'CMIG4', 'CIEL3', 'COGN3', 'CPLE6', 'CSAN3', 'CPFE3',
#        'CMIN3', 'CVCB3', 'CYRE3', 'DXCO3', 'ELET3', 'ELET6', 'EMBR3', 'ENBR3',
#        'ENGI11', 'ENEV3', 'EGIE3', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4',
#        'GOLL4', 'NTCO3', 'SOMA3', 'HAPV3', 'HYPE3', 'IGTI11', 'IRBR3', 'ITSA4',
#        'ITUB4', 'JBSS3', 'KLBN11', 'RENT3', 'LWSA3', 'LREN3', 'MGLU3', 'MRFG3',
#        'CASH3', 'BEEF3', 'MRVE3', 'MULT3', 'PCAR3', 'PETR3', 'PETR4', 'PRIO3',
#        'PETZ3', 'RADL3', 'RAIZ4', 'RDOR3', 'RAIL3', 'SBSP3', 'SANB11', 'SMTO3',
#        'CSNA3', 'SLCE3', 'SUZB3', 'TAEE11', 'VIVT3', 'TIMS3', 'TOTS3', 'UGPA3',
#        'USIM5', 'VALE3', 'VIIA3', 'VBBR3', 'WEGE3', 'YDUQ3'],
#       dtype='object')

# %%
tickers = list(pd.read_csv('/content/IBOVDia_10-07-23.csv', encoding='latin-1', sep=';', header=1).index[0:-2])

# %%
tickers_novo = [i + '.SA' for i in tickers]

# %%
import yfinance as yf

# %%
ibov = yf.download(tickers_novo, start = '2023-01-01')
# Out:
# [*********************100%***********************]  86 of 86 completed

# %%
ibov.head()
# Out:
#            Adj Close                                                     \
#             ABEV3.SA ALPA4.SA   ALSO3.SA   ARZZ3.SA   ASAI3.SA AZUL4.SA
# Date
# 2023-01-02     14.19    14.33  15.826699  73.323433  18.912775    10.30
# 2023-01-03     14.17    13.40  15.146190  71.038254  18.534321    10.16
# 2023-01-04     14.25    13.49  15.292012  72.670517  19.002409    10.56
# 2023-01-05     14.29    13.86  15.787812  73.541061  18.902815    11.55
# 2023-01-06     14.32    13.87  16.244724  74.985374  18.962574    11.84
#
#                                                         ...    Volume  \
#              B3SA3.SA   BBAS3.SA   BBDC3.SA   BBDC4.SA  ...  TIMS3.SA
# Date                                                    ...
# 2023-01-02  12.039818  31.615412  12.395083  13.879214  ...   2774100
# 2023-01-03  11.636853  31.026068  11.809099  13.190462  ...   6118000
# 2023-01-04  11.725309  31.425304  11.912604  13.228148  ...   7847200
# ...

# %%
ibov = yf.download(tickers_novo, start = '2023-01-01')['Close']
# Out:
# [*********************100%***********************]  86 of 86 completed

# %%
ibov.head()
# Out:
#             ABEV3.SA  ALPA4.SA   ALSO3.SA   ARZZ3.SA   ASAI3.SA  AZUL4.SA  \
# Date
# 2023-01-02     14.19     14.33  16.280001  74.120003  18.990000     10.30
# 2023-01-03     14.17     13.40  15.580000  71.809998  18.610001     10.16
# 2023-01-04     14.25     13.49  15.730000  73.459999  19.080000     10.56
# 2023-01-05     14.29     13.86  16.240000  74.339996  18.980000     11.55
# 2023-01-06     14.32     13.87  16.709999  75.800003  19.040001     11.84
#
#             B3SA3.SA   BBAS3.SA  BBDC3.SA  BBDC4.SA  ...  TIMS3.SA   TOTS3.SA  \
# Date                                                 ...
# 2023-01-02     12.25  33.259998     13.19     14.75  ...     11.98  25.889999
# 2023-01-03     11.84  32.639999     12.55     14.00  ...     11.69  25.000000
# 2023-01-04     11.93  33.060001     12.66     14.04  ...     11.90  25.730000
# 2023-01-05     12.30  34.570000     13.07     14.65  ...     11.79  26.900000
# ...

# %%
ibov.plot(figsize = (10,8));
