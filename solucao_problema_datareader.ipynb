# %%
# !pip install -U streamlit
# Out:
# ...
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 0.85.1
#     Uninstalling streamlit-0.85.1:
#       Successfully uninstalled streamlit-0.85.1
# ...

# %%
# !pip install -U pandas_datareader

# %%
# !pip install -U yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23909 sha256=d0d85bf74caf553dfbfc1eb2ca1819c7d2de91d3da8b37d4a835f77ee1cddfe4
#   Stored in directory: c:\users\pivetta\appdata\local\pip\cache\wheels\ec\cc\c1\32da8ee853d742d5d7cbd11ee04421222eb354672020b57297
# Successfully built yfinance
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.59
#     Uninstalling yfinance-0.1.59:
#       Successfully uninstalled yfinance-0.1.59
# ...

# %%
import pandas_datareader as pdr

import yfinance as yf
yf.pdr_override()

# %%
pdr.data.get_data_yahoo('NIO',start='2019-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-01-02   6.130000   6.240000   6.000000   6.200000   6.200000   8823600
# 2019-01-03   6.100000   6.150000   6.020000   6.050000   6.050000   7562900
# 2019-01-04   6.190000   6.400000   6.130000   6.360000   6.360000   9405600
# 2019-01-07   6.410000   6.590000   6.310000   6.500000   6.500000   9709000
# 2019-01-08   6.570000   6.580000   6.170000   6.400000   6.400000   9603800
# ...               ...        ...        ...        ...        ...       ...
# 2021-07-02  51.259998  51.470001  48.529999  50.400002  50.400002  78631100
# 2021-07-06  49.400002  51.740002  49.180000  50.290001  50.290001  67705500
# 2021-07-07  50.200001  50.549999  45.750000  46.040001  46.040001  85812800
# 2021-07-08  43.860001  46.259998  42.730000  45.599998  45.599998  93774800
# ...
